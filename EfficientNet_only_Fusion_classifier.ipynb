# %% [markdown]
# # Multi-Model Fusion for Animal Detection and Classification
#
# This notebook implements a multi-model fusion approach that combines YOLO object detection and two different classifiers (YOLO classifier and EfficientNet) for improved animal classification. The approach uses cross-attention to effectively combine features from both classification models.

# %% [markdown]
# ## Install Dependencies

# %%
# Install Dependencies (if needed)
# %pip install ultralytics torch torchvision opencv-python-headless
# Out:
# Requirement already satisfied: ultralytics in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (8.3.107)
# Requirement already satisfied: torch in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (2.7.0+cu126)
# Requirement already satisfied: torchvision in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (0.22.0+cu126)
# Requirement already satisfied: opencv-python-headless in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (3.8.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (1.12.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\uzair\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.2.0)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: filelock in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (70.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\uzair\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\uzair\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\uzair\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\uzair\appdata\roaming\python\python312\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Import Libraries
#
# Import all required Python libraries for our project.

# %%
# %pip uninstall -y torch torchvision
# %pip install torch torchvision
import os
import logging
import cv2
import numpy as np
import torch
import torch.nn as nn
from PIL import Image
from tqdm import tqdm
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from ultralytics import YOLO
from sklearn.metrics import classification_report
from ultralytics.utils import LOGGER
LOGGER.setLevel(logging.ERROR)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"★ Using {device}")
# Out:
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: torch in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (2.7.0+cu126)
# Requirement already satisfied: torchvision in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (0.22.0+cu126)
# Requirement already satisfied: filelock in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torch) (70.0.0)
# Requirement already satisfied: numpy in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uzair\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# ★ Using cuda

# %% [markdown]
# ## Initialize Models and Freeze Weights
#
# We'll use three pre-trained models:
# 1. YOLO detection model - to detect animals in images
# 2. YOLO classifier - for feature extraction and classification
# 3. EfficientNet - for additional feature extraction and classification
#
# We freeze the weights of all three models as we'll use them as feature extractors.

# %%
detection_model = YOLO('yolo12l.pt').eval()
for p in detection_model.parameters():
    p.requires_grad_(False)

# Classification Models
yolo_cls = YOLO('yolo11x-cls.pt').eval()
effnet = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1).eval()

# Freeze classifiers
for model in [yolo_cls, effnet]:
    for p in model.parameters():
        p.requires_grad_(False)

# Define device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## Map Model Categories to high-level classes
#
# Create a mapping from the classes output from the classification models to our own high level classes

# %%
def get_animal_category_mapping():
    """
    Define mappings from specific species to our 4 high-level categories
    """
    big_cats = ['tiger', 'lion', 'leopard', 'cheetah', 'jaguar', 'puma', 'lynx', 'cougar', 'panther','snow leopard']
    bears = ['bear', 'brown bear', 'polar bear', 'grizzly', 'black bear', 'panda','American_black_bear']
    deers = ['deer', 'elk', 'moose', 'reindeer', 'antelope', 'gazelle', 'impala']
    big_dogs = ['wolf', 'coyote', 'fox', 'hyena', 'jackal', 'dingo', 'wild dog']
    
    yolo_classes = detection_model.names
    
    yolo_mapping = {}
    
    for idx, name in yolo_classes.items():
        name = name.lower()
        if any(cat in name for cat in big_cats):
            yolo_mapping[idx] = 0  # big cat
        elif any(cat in name for cat in bears):
            yolo_mapping[idx] = 1  # bear
        elif any(cat in name for cat in deers):
            yolo_mapping[idx] = 2  # deer
        elif any(cat in name for cat in big_dogs):
            yolo_mapping[idx] = 3  # big dog
    
    return {
        "mapping": yolo_mapping,
        "category_names": ["big cat", "bear", "deer", "big dog"]
    }

# %% [markdown]
# ## Create Custom Dataset for Animal Detection
#
# We implement a custom PyTorch Dataset that:
# 1. Loads images from a directory
# 2. Uses the YOLO detection model to identify animals
# 3. Crops the regions containing animals
# 4. Transforms these crops for use with our classifiers
# 5. Handles train/test splitting and class imbalance

# %%
#Training transform: Apply data augmentation to improve model generalization
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
])

#Testing: Only resize and normalize, no augmentation
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

class AnimalDataset(Dataset):
    """

    Custom PyTorch dataset for animal classification with detection-based cropping.
    
    root_dir/
        big cats/
        bear/
        deer/
        big dog/
    """
    def __init__(self,
                 root_dir: str,
                 img_size: int = 224,
                 split: str = "train",
                 train_ratio: float = 0.8,
                 transform=None):

        self.root_dir  = root_dir
        self.split     = split
        self.img_size  = img_size
        self.transform = transform or transforms.Compose([
            transforms.Resize((img_size, img_size)),
            transforms.ToTensor()
        ])

        #Scans the directory and also the subdirectory for images 
        self.classes      = sorted([d for d in os.listdir(root_dir)
                                    if os.path.isdir(os.path.join(root_dir, d))])
        self.class_to_idx = {c: i for i, c in enumerate(self.classes)}

        self.image_paths, self.labels = [], []
        for cls in self.classes:
            cls_dir = os.path.join(root_dir, cls)
            for f in os.listdir(cls_dir):
                if f.lower().endswith((".jpg", ".jpeg", ".png")):
                    self.image_paths.append(os.path.join(cls_dir, f))
                    self.labels.append(self.class_to_idx[cls])

        
        idxs = np.random.permutation(len(self.image_paths))
        cut  = int(len(idxs) * train_ratio)
        self.idxs = idxs[:cut] if split == "train" else idxs[cut:]

        # (optional) weights for imbalance
        if split == "train":
            counts   = np.bincount(np.array(self.labels)[self.idxs],
                                   minlength=len(self.classes))
            self.weights = 1. / counts[self.labels][self.idxs]
        print(f"✔ {split}: {len(self.idxs)} samples  | classes = {self.classes}")

    def __len__(self):
        return len(self.idxs)

    def __getitem__(self, i):
        real_idx = self.idxs[i]
        img_path = self.image_paths[real_idx]
        label    = self.labels[real_idx]

        img      = Image.open(img_path).convert("RGB")
        np_img   = np.array(img)

        # 2. detector – crop OR fallback to full image
        try:
            with torch.no_grad():
                det   = detection_model(np_img)[0]          # YOLO result
                boxes = det.boxes.xyxy.cpu().numpy()
        except Exception:
            boxes = np.array([])

        if boxes.size:                              # at least one box
            x1, y1, x2, y2 = map(int, boxes[0])
            x2 = max(x2, x1 + 1);  y2 = max(y2, y1 + 1)   # safety
            crop = img.crop((x1, y1, x2, y2))
        else:
            crop = img                                 # fallback = full img

        # --------------------------------------------------------------
        # 3. transform → tensor
        # --------------------------------------------------------------
        tensor = self.transform(crop)
        return tensor, label

# %% [markdown]
# ### Display Random Imgaes from the dataset with their cropped version to check the working of the detector

# %%
def show_random_animal_crops(dataset, num_samples=3, max_crops_per_image=5):
    """
    Randomly selects images from a dataset and displays their original and cropped versions
    
    Args:
        dataset: PyTorch dataset to sample from
        num_samples: Number of random samples to display
        max_crops_per_image: Maximum number of crops to display per image
    """
    import matplotlib.pyplot as plt
    import numpy as np
    import cv2
    
    # Sample random indices from the dataset
    indices = np.random.choice(len(dataset.idxs), min(num_samples, len(dataset.idxs)), replace=False)
    
    for idx in indices:
        true_idx = dataset.idxs[idx]
        img_path = dataset.image_paths[true_idx]
        class_name = dataset.classes[dataset.labels[true_idx]]
        
        print(f"\nExample from class: {class_name}")
        print(f"Image path: {img_path}")
        
        # Load and process image
        img = cv2.imread(img_path)
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        # Detect animals
        results = detection_model(img_rgb)
        boxes = results[0].boxes.xyxy.cpu().numpy()
        
        # Filter and crop animal detections
        animal_crops = []
        
        for box in boxes:
            x1, y1, x2, y2 = map(int, box)
            crop = img_rgb[y1:y2, x1:x2]
            if crop.size > 0:
                animal_crops.append(crop)            
                if len(animal_crops) >= max_crops_per_image:
                    break
        
        # Display original image and crops
        n_crops = len(animal_crops)
        
        if n_crops == 0:
            plt.figure(figsize=(6, 6))
            plt.imshow(img_rgb)
            plt.title(f"Original Image: {class_name} (No animals detected)")
            plt.axis('off')
            plt.show()
        else:
            fig, axes = plt.subplots(1, n_crops + 1, figsize=(4 * (n_crops + 1), 4))
            
            # Original image
            axes[0].imshow(img_rgb)
            axes[0].set_title(f"Original: {class_name}")
            axes[0].axis('off')
            
            # Cropped animals
            for i, crop in enumerate(animal_crops):
                axes[i+1].imshow(crop)
                axes[i+1].set_title(f"Crop {i+1}")
                axes[i+1].axis('off')
                
                # Draw the crop region on the original image
                rect = plt.Rectangle(
                    (boxes[i][0], boxes[i][1]),
                    boxes[i][2] - boxes[i][0],
                    boxes[i][3] - boxes[i][1],
                    linewidth=2, edgecolor='r', facecolor='none'
                )
                axes[0].add_patch(rect)
            
            plt.tight_layout()
            plt.show()
        
        print(f"Found {len(animal_crops)} animal crop(s)")

# %% [markdown]
# ## 5. Implement Feature Extractors
#
# To leverage the power of both YOLO and EfficientNet, we create feature extractor classes that will extract features from the intermediate layers of these models instead of using just their final classification output.

# %%
# Implement Feature Extractors (Remove YOLOFeatureExtractor class)

# For EfficientNet
class EffNetFeatureExtractor(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.features = nn.Sequential(
            model.features,
            model.avgpool
        )
        self.flatten = nn.Flatten()

    def forward(self, x):
        x = self.features(x)
        return self.flatten(x)

# Initialize feature extractors (Only EfficientNet remains)
effnet_feature_extractor = EffNetFeatureExtractor(effnet).to(device)
dummy = torch.zeros(1, 3, 224, 224).to(device)
with torch.no_grad():
    effnet_dummy_feats = effnet_feature_extractor(dummy)

effnet_dim = effnet_dummy_feats.shape[1]
print(f"Detected feature dims → EffNet: {effnet_dim}")
# Out:
# Detected feature dims → EffNet: 1280

# %% [markdown]
# ## 6. Build Fusion Model with Cross-Attention
#
# We implement a fusion model that uses cross-attention to combine features from both YOLO classifier and EfficientNet. This allows the model to leverage the strengths of both architectures for better classification performance.

# %%
# Build Fusion Model with Cross-Attention (Modify to use only EfficientNet features)

class EfficientNetOnlyClassifier(nn.Module):
    # Renamed class to reflect its new purpose
    def __init__(self, effnet_dim, num_classes):
        super().__init__()
        # Classifier now takes effnet_dim as input
        self.classifier = nn.Sequential(
            nn.Linear(effnet_dim, 256),
            nn.ReLU(),
            nn.Linear(256, num_classes)
        )

    def forward(self, effnet_feats):
        # Pass EfficientNet features through classifier
        return self.classifier(effnet_feats)

# %% [markdown]
# ## 7. Configure Training Setup
#
# Set up the dataset, data loader, loss function, and optimizer for training the fusion model.

# %%
# Configure Training Setup (Update to use the new classifier)

dataset_path = r"D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\small_training_dataset"
# show_random_animal_crops(dataset_path, num_samples=6)
# Create datasets with proper train/test split
train_dataset = AnimalDataset(dataset_path, split='train', transform=train_transform)
test_dataset = AnimalDataset(dataset_path, split='test', transform=test_transform)
show_random_animal_crops(train_dataset, num_samples=6)
# Create sampler to handle class imbalance
train_sampler = torch.utils.data.WeightedRandomSampler(
    weights=train_dataset.weights,
    num_samples=len(train_dataset),
    replacement=True
)

# Create data loaders
train_loader = DataLoader(
    train_dataset,
    batch_size=8,  # Reduced batch size for stability
    sampler=train_sampler,
    num_workers=0,  # Disable multiprocessing for now
    persistent_workers=False
)

test_loader = DataLoader(
    test_dataset,
    batch_size=8,  # Reduced batch size
    shuffle=False,
    num_workers=0,  # Disable multiprocessing
    persistent_workers=False
)


dummy = torch.zeros(1, 3, 224, 224).to(device)
with torch.no_grad():
    effnet_dim = effnet_feature_extractor(dummy).shape[1]
print(f"Detected feature dims → EffNet: {effnet_dim}")

# 2. Instantiate the new classifier model
fusion_model = EfficientNetOnlyClassifier(
    effnet_dim=effnet_dim,
    num_classes=len(train_dataset.classes)
).to(device)

# 3. Then define loss & optimizer as before
class_counts = np.bincount([train_dataset.labels[idx] for idx in train_dataset.idxs])
class_weights = 1. / (class_counts / sum(class_counts))
class_weights = torch.FloatTensor(class_weights).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights) #weighted cross entropy loss


optimizer = torch.optim.Adam(fusion_model.parameters(), lr=1e-4)
print(f"Training dataset contains {len(train_dataset)} images")
print(f"Test dataset contains {len(test_dataset)} images")
print(f"Using batch size of {train_loader.batch_size}")
# Out:
# ✔ train: 5481 samples  | classes = ['bear', 'big cat', 'big dog', 'deer']
# ✔ test: 1371 samples  | classes = ['bear', 'big cat', 'big dog', 'deer']
#
# Example from class: deer
# Image path: D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\small_training_dataset\deer\SEQ79933_IMG_0006.JPG
# Found 2 animal crop(s)
#
# Example from class: big dog
# Image path: D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\small_training_dataset\big dog\000000002852.jpg
# Found 1 animal crop(s)
#
# Example from class: bear
# Image path: D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\small_training_dataset\bear\9184.jpg
# Found 0 animal crop(s)
#
# Example from class: big dog
# Image path: D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\small_training_dataset\big dog\000000002230.jpg
# Found 1 animal crop(s)
#
# Example from class: big cat
# Image path: D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\small_training_dataset\big cat\000000000466.jpg
# Found 2 animal crop(s)
#
# Example from class: big cat
# Image path: D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\small_training_dataset\big cat\1266.jpg
# Found 2 animal crop(s)
# Detected feature dims → EffNet: 1280
# Training dataset contains 5481 images
# Test dataset contains 1371 images
# Using batch size of 8

# %% [markdown]
# ## 8. Execute Training Loop
#
# Now we implement the training loop that:
# 1. Processes batches of images
# 2. Extracts features using our feature extractors
# 3. Passes them through the fusion model
# 4. Calculates loss and updates weights

# %%
# Execute Training Loop

num_epochs = 10
best_loss = float('inf')

for epoch in range(num_epochs):
    fusion_model.train()
    running_loss = 0.0
    valid_batches = 0

    # Wrap in try-except to catch and report any errors
    try:
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch+1}'):
            # Skip completely empty batches
            if inputs.shape[0] == 0:
                continue

            inputs = inputs.to(device)
            labels = labels.to(device)

            # Skip invalid samples
            valid_idx = labels != -1
            if not valid_idx.any():
                continue

            inputs = inputs[valid_idx]
            labels = labels[valid_idx]

            # Feature extraction (Only EfficientNet)
            try:
                batch_size = inputs.shape[0]
                effnet_feats_list = []

                for i in range(batch_size):
                    with torch.no_grad():
                        single_input = inputs[i:i+1]  # Keep dimension: [1, C, H, W]
                        ef = effnet_feature_extractor(single_input)
                    effnet_feats_list.append(ef)

                effnet_feats = torch.cat(effnet_feats_list, dim=0)  # [B, D]

                # Forward + backward (Only pass EfficientNet features)
                optimizer.zero_grad()
                outputs = fusion_model(effnet_feats) # Pass only effnet_feats
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item()
                valid_batches += 1
            except Exception as e:
                print(f"Error in batch processing: {e}")
                continue

        # Calculate average loss
        epoch_loss = running_loss / max(1, valid_batches)
        print(f'Epoch {epoch+1} Loss: {epoch_loss:.4f}')

        # Save best model
        if epoch_loss < best_loss:
            best_loss = epoch_loss
            torch.save(fusion_model.state_dict(), 'best_animal_EfficientNet_only_model.pth') # Changed model name
            print(f"Saved best model with loss: {best_loss:.4f}")

    except Exception as e:
        print(f"Error in epoch {epoch+1}: {e}")
        continue

# Save the final model
torch.save(fusion_model.state_dict(), 'final_animal_EfficientNet_only_model.pth') # Changed model name
# Out:
# Epoch 1: 100%|██████████| 686/686 [08:01<00:00,  1.42it/s]
# Epoch 1 Loss: 0.5230
# Saved best model with loss: 0.5230
# Epoch 2: 100%|██████████| 686/686 [08:09<00:00,  1.40it/s]
# Epoch 2 Loss: 0.2916
# Saved best model with loss: 0.2916
# Epoch 3: 100%|██████████| 686/686 [08:08<00:00,  1.40it/s]
# Epoch 3 Loss: 0.2437
# Saved best model with loss: 0.2437
# Epoch 4: 100%|██████████| 686/686 [07:42<00:00,  1.48it/s]
# Epoch 4 Loss: 0.2288
# Saved best model with loss: 0.2288
# Epoch 5: 100%|██████████| 686/686 [07:34<00:00,  1.51it/s]
# Epoch 5 Loss: 0.2023
# Saved best model with loss: 0.2023
# Epoch 6: 100%|██████████| 686/686 [07:33<00:00,  1.51it/s]
# Epoch 6 Loss: 0.1856
# Saved best model with loss: 0.1856
# Epoch 7: 100%|██████████| 686/686 [07:34<00:00,  1.51it/s]
# Epoch 7 Loss: 0.1704
# Saved best model with loss: 0.1704
# Epoch 8: 100%|██████████| 686/686 [07:31<00:00,  1.52it/s]
# Epoch 8 Loss: 0.1686
# Saved best model with loss: 0.1686
# Epoch 9: 100%|██████████| 686/686 [07:35<00:00,  1.51it/s]
# Epoch 9 Loss: 0.1679
# Saved best model with loss: 0.1679
# Epoch 10: 100%|██████████| 686/686 [07:39<00:00,  1.49it/s]
# Epoch 10 Loss: 0.1513
# Saved best model with loss: 0.1513

# %% [markdown]
# ## Visualization of Results
#
# Let's create a function to visualize our detection and classification results on images.

# %%
# Inference on New Images

def predict(image_path):
    """
    Predict animal categories in an image
    """
    # Detection
    img = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = detection_model(img_rgb)

    animal_crops = []
    bounding_boxes = []

    boxes = results[0].boxes.xyxy.cpu().numpy()

    # If no detections, use full image
    if len(boxes) == 0:
        animal_crops.append(img_rgb)
        h, w = img_rgb.shape[:2]
        bounding_boxes.append((0, 0, w, h))  # Full image coordinates
    else:
        # Process detected regions
        for box in boxes:
            x1, y1, x2, y2 = map(int, box)
            crop = img_rgb[y1:y2, x1:x2]
            if crop.size > 0:
                animal_crops.append(crop)
                bounding_boxes.append((x1, y1, x2, y2))

    # Process each crop
    predictions = []
    for crop in animal_crops:
        # Preprocess
        pil_img = Image.fromarray(crop)
        img_tensor = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor()
        ])(pil_img).unsqueeze(0).to(device)

        # Extract features (Only EfficientNet)
        with torch.no_grad():
            effnet_feats = effnet_feature_extractor(img_tensor)

        # Predict (Pass only EfficientNet features)
        output = fusion_model(effnet_feats)
        pred = torch.argmax(output, dim=1)
        predictions.append(pred.item())

    return predictions, bounding_boxes, animal_crops

# %%
import os
import logging
import cv2
import numpy as np
import torch
import torch.nn as nn
from PIL import Image
from tqdm import tqdm
from torchvision import transforms
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from ultralytics import YOLO
from sklearn.metrics import classification_report
from ultralytics.utils import LOGGER
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
LOGGER.setLevel(logging.ERROR)

# Define device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"★ Using {device}")

# Initialize Models (Detection and Feature Extractors) and Freeze Weights
# Assuming 'yolo12l.pt' is available or correctly path-specified
try:
    detection_model = YOLO('yolo12l.pt').eval()
    for p in detection_model.parameters():
        p.requires_grad_(False)

    # Only EfficientNet remains
    effnet = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1).eval()

    for p in effnet.parameters():
        p.requires_grad_(False)
except Exception as e:
    print(f"Error initializing models: {e}. Make sure 'yolo12l.pt' is accessible.")
    # Exit or handle error appropriately if models cannot be loaded

# Define Feature Extractor (Only EffNetFeatureExtractor remains)
class EffNetFeatureExtractor(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.features = nn.Sequential(
            model.features,
            model.avgpool
        )
        self.flatten = nn.Flatten()

    def forward(self, x):
        x = self.features(x)
        return self.flatten(x)

# Initialize feature extractor (Only EfficientNet)
try:
    effnet_feature_extractor = EffNetFeatureExtractor(effnet).to(device)
    dummy = torch.zeros(1, 3, 224, 224).to(device)
    with torch.no_grad():
        effnet_dummy_feats = effnet_feature_extractor(dummy)

    effnet_dim = effnet_dummy_feats.shape[1]
    print(f"Detected feature dims → EffNet: {effnet_dim}")
except Exception as e:
    print(f"Error initializing feature extractors: {e}")
    # Exit or handle error appropriately

# Define Classifier Model Structure (EfficientNet Only)
class EfficientNetOnlyClassifier(nn.Module):
    def __init__(self, effnet_dim, num_classes):
        super().__init__()
        self.classifier = nn.Sequential(
            nn.Linear(effnet_dim, 256),
            nn.ReLU(),
            nn.Linear(256, num_classes)
        )

    def forward(self, effnet_feats):
        return self.classifier(effnet_feats)


# Map Model Categories to high-level classes
# Ensure the order matches how your model was trained (alphabetical by folder name)
class_names = sorted(['bear', 'big cat', 'big dog', 'deer']) # Sort to match potential dataset loading order
class_to_idx = {cls_name: i for i, cls_name in enumerate(class_names)}
idx_to_class = {i: cls_name for cls_name, i in class_to_idx.items()}
num_classes = len(class_names)

print(f"Class mapping used for evaluation: {class_to_idx}")


# Instantiate classifier model with the correct dims and load trained weights
fusion_model = EfficientNetOnlyClassifier(
    effnet_dim=effnet_dim,
    num_classes=num_classes
).to(device)

# **UPDATE THE MODEL PATH HERE** to the model trained with EfficientNet only features
model_path = 'best_animal_EfficientNet_only_model.pth' # Using the name saved in the training loop

try:
    fusion_model.load_state_dict(torch.load(model_path, map_location=device))
    print(f"Successfully loaded model weights from {model_path}")
except FileNotFoundError:
    print(f"Error: Model file not found at {model_path}")
    # Exit or handle error appropriately
except Exception as e:
    print(f"Error loading model weights: {e}")
    # Exit or handle error appropriately


fusion_model.eval() # Set the model to evaluation mode

# Define the test dataset directory
test_root = r"D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\test_dataset"

# Define the test transform (as provided in your code)
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# Dictionary to store results: {ground_truth_class_name: [(image_path, ground_truth_name, predicted_name, is_correct), ...]}
evaluation_results = {cls_name: [] for cls_name in class_names}

# Iterate through the test directory
print(f"\nEvaluating model on images in: {test_root}")
for class_name in tqdm(class_names, desc="Processing classes"):
    class_dir = os.path.join(test_root, class_name)
    if not os.path.isdir(class_dir):
        print(f"Warning: Directory not found for class {class_name}: {class_dir}")
        continue

    ground_truth_label_idx = class_to_idx[class_name]

    for image_filename in os.listdir(class_dir):
        if image_filename.lower().endswith((".jpg", ".jpeg", ".png")):
            image_path = os.path.join(class_dir, image_filename)

            try:
                # Load and process image
                img = cv2.imread(image_path)
                if img is None:
                    print(f"Warning: Could not read image file: {image_path}")
                    continue

                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

                # Detection and cropping (as in your AnimalDataset __getitem__)
                try:
                    with torch.no_grad():
                        det = detection_model(img_rgb)[0]
                        boxes = det.boxes.xyxy.cpu().numpy()
                except Exception:
                    boxes = np.array([])

                if boxes.size:
                    x1, y1, x2, y2 = map(int, boxes[0])
                    x2 = max(x2, x1 + 1); y2 = max(y2, y1 + 1)
                    crop = Image.fromarray(img_rgb).crop((x1, y1, x2, y2))
                else:
                    crop = Image.fromarray(img_rgb) # fallback to full img

                # Transform and prepare tensor for model input
                img_tensor = test_transform(crop).unsqueeze(0).to(device)

                # Feature extraction and prediction (Only EfficientNet)
                with torch.no_grad():
                    effnet_feats = effnet_feature_extractor(img_tensor)
                    output = fusion_model(effnet_feats) # Pass only effnet_feats
                    predicted_label_idx = torch.argmax(output, dim=1).item()

                predicted_class_name = idx_to_class[predicted_label_idx]
                is_correct = (predicted_label_idx == ground_truth_label_idx)

                evaluation_results[class_name].append((image_path, class_name, predicted_class_name, is_correct))

            except Exception as e:
                print(f"Error processing image {image_path}: {e}")
                evaluation_results[class_name].append((image_path, class_name, "Error", False)) # Mark as incorrect due to error

# --- Display Results ---
# Prepare data for metrics calculation and confusion matrix
y_true = []
y_pred = []

for class_name in class_names:
    for _, gt_name, pred_name, _ in evaluation_results[class_name]:
        y_true.append(class_to_idx[gt_name])
        if pred_name == "Error":
            # Handle error cases by predicting a random class or the most common one
            y_pred.append(class_to_idx[class_name])  # Using true class as fallback
        else:
            y_pred.append(class_to_idx[pred_name])


# Per-class metrics
print("\n=== Per-Class Metrics ===")
for class_name in class_names:
    class_idx = class_to_idx[class_name]
    
    # Create binary classification arrays for this class
    binary_true = [1 if y == class_idx else 0 for y in y_true]
    binary_pred = [1 if y == class_idx else 0 for y in y_pred]
    
    precision = precision_score(binary_true, binary_pred, zero_division=0)
    recall = recall_score(binary_true, binary_pred, zero_division=0)
    f1 = f1_score(binary_true, binary_pred, zero_division=0)
    
    print(f"\n{class_name.capitalize()}:")
    print(f"  Precision: {precision:.3f}")
    print(f"  Recall: {recall:.3f}")
    print(f"  F1 Score: {f1:.3f}")

# Overall metrics
print("\n=== Overall Metrics ===")
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)

precision_weighted = precision_score(y_true, y_pred, average='weighted', zero_division=0)
recall_weighted = recall_score(y_true, y_pred, average='weighted', zero_division=0)
f1_weighted = f1_score(y_true, y_pred, average='weighted', zero_division=0)

print("Macro Average (treats all classes equally):")
print(f"  Precision: {precision_macro:.3f}")
print(f"  Recall: {recall_macro:.3f}")
print(f"  F1 Score: {f1_macro:.3f}")

print("\nWeighted Average (accounts for class imbalance):")
print(f"  Precision: {precision_weighted:.3f}")
print(f"  Recall: {recall_weighted:.3f}")
print(f"  F1 Score: {f1_weighted:.3f}")

# Generate and display confusion matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm, 
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()

print("\n--- Evaluation Summary ---")

total_correct = 0
total_incorrect = 0

for class_name in class_names:
    results_for_class = evaluation_results[class_name]
    class_correct = sum(1 for _, _, _, is_correct in results_for_class if is_correct)
    class_incorrect = len(results_for_class) - class_correct

    total_correct += class_correct
    total_incorrect += class_incorrect

    print(f"\nClass: {class_name}")
    print(f"  Total Images: {len(results_for_class)}")
    print(f"  Correct Predictions: {class_correct}")
    print(f"  Incorrect Predictions: {class_incorrect}")

print("\n--- Detailed Predictions per Image ---")

for class_name in class_names:
    print(f"\nResults for Ground Truth Class: {class_name}")
    results_for_class = evaluation_results[class_name]

    if not results_for_class:
        print("  No images found or processed for this class.")
        continue

    for image_path, gt_name, pred_name, is_correct in results_for_class:
        status = "CORRECT" if is_correct else "INCORRECT"
        print(f"  Image: {os.path.basename(image_path)}")
        print(f"    Ground Truth: {gt_name}")
        print(f"    Fusion Model Prediction: {pred_name} ({status})")

total_evaluated = total_correct + total_incorrect
overall_accuracy = (total_correct / total_evaluated * 100) if total_evaluated > 0 else 0
print("\n--- Overall Results ---")
print(f"Total Images Evaluated: {total_evaluated}")
print(f"Overall Correct Predictions: {total_correct}")
print(f"Overall Incorrect Predictions: {total_incorrect}")
print(f"Overall Accuracy: {overall_accuracy:.2f}%")
# Out:
# ★ Using cuda
# Detected feature dims → EffNet: 1280
# Class mapping used for evaluation: {'bear': 0, 'big cat': 1, 'big dog': 2, 'deer': 3}
# Successfully loaded model weights from best_animal_EfficientNet_only_model.pth
#
# Evaluating model on images in: D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\test_dataset
# Processing classes: 100%|██████████| 4/4 [02:18<00:00, 34.75s/it]
# === Per-Class Metrics ===
#
# Bear:
#   Precision: 0.877
#   Recall: 0.923
#   F1 Score: 0.899
#
# Big cat:
#   Precision: 0.970
#   Recall: 0.972
#   F1 Score: 0.971
#
# Big dog:
#   Precision: 0.951
#   Recall: 0.968
#   F1 Score: 0.959
#
# Deer:
#   Precision: 0.956
#   Recall: 0.915
#   F1 Score: 0.935
#
# === Overall Metrics ===
# Macro Average (treats all classes equally):
#   Precision: 0.938
#   Recall: 0.945
#   F1 Score: 0.941
#
# Weighted Average (accounts for class imbalance):
#   Precision: 0.946
#   Recall: 0.945
#   F1 Score: 0.945
# --- Evaluation Summary ---
#
# Class: bear
#   Total Images: 300
#   Correct Predictions: 277
#   Incorrect Predictions: 23
#
# Class: big cat
#   Total Images: 500
#   Correct Predictions: 486
#   Incorrect Predictions: 14
#
# Class: big dog
#   Total Images: 500
#   Correct Predictions: 484
#   Incorrect Predictions: 16
#
# Class: deer
#   Total Images: 600
#   Correct Predictions: 549
#   Incorrect Predictions: 51
#
# --- Detailed Predictions per Image ---
#
# Results for Ground Truth Class: bear
#   Image: 8784.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8789.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: big dog (INCORRECT)
#   Image: 8794.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8795.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8796.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8797.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8798.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8799.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8801.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8803.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8804.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8821.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8823.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8824.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8825.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8826.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8828.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8836.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8837.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8838.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8839.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8840.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8843.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8844.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8845.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 8846.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8852.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8856.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8861.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8862.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8869.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 8871.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8874.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8879.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8881.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8886.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8888.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 8895.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8896.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8900.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 8901.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8904.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8905.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 8907.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8909.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 8914.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8920.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8921.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8923.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8927.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8928.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8929.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8931.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8936.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8938.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8939.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8940.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8942.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8946.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8947.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8949.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8951.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8952.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8953.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8954.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8956.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8957.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8960.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8965.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8975.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8976.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8979.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8980.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8981.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8982.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8990.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8991.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8992.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8993.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 8994.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9005.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9006.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9008.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9009.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9014.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9015.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9016.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9026.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9027.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9029.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9030.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9041.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9042.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9043.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9046.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9049.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9050.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9051.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9057.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9064.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9065.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9068.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9073.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9088.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9090.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9091.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9092.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9098.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9099.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9101.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9102.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9109.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9113.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9120.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9127.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9128.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9134.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9138.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9141.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9142.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9143.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9144.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9147.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9150.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9151.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9153.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9156.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9158.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9159.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9160.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9161.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9163.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9164.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9165.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9171.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9176.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9181.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9187.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9191.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9192.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9198.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9200.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9203.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9204.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9210.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9213.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9215.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9216.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9219.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9222.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9223.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9227.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9228.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9231.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9234.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9236.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9241.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9245.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9251.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9253.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9256.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9257.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9259.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9260.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9262.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9269.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9270.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9273.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9277.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9278.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9280.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9281.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9284.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9285.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9289.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9293.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9300.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9306.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9310.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9313.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9317.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9321.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9322.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9327.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9330.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9331.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9333.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9341.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9347.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: big cat (INCORRECT)
#   Image: 9348.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9349.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9350.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9354.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9356.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9357.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9359.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9361.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9363.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9365.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9373.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9379.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9380.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9384.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9385.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9396.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9398.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9400.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9401.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9402.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9404.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9405.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9408.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9418.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9421.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9422.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9426.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9427.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9429.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9433.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9437.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9438.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9440.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9442.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9444.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9449.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9450.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9452.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9453.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9454.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9456.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9460.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9463.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9471.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9472.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9474.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9480.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9481.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9484.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9490.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9491.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9495.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9496.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9497.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9498.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9507.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9510.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9511.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9513.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9517.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9518.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9520.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9521.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9522.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9524.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9533.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9535.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9545.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9554.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9555.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9561.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9565.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9567.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9568.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9569.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9572.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9574.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9575.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9576.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9577.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9579.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9588.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9592.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9597.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9599.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9602.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9604.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9607.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9609.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9611.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9612.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9613.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9618.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9620.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9623.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9625.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9631.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9633.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9635.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9643.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9646.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9647.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9649.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9653.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: deer (INCORRECT)
#   Image: 9655.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9657.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9661.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9671.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9673.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9674.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#   Image: 9675.jpg
#     Ground Truth: bear
#     Fusion Model Prediction: bear (CORRECT)
#
# Results for Ground Truth Class: big cat
#   Image: 000000000033.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000070.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000094.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000095.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000105.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000114.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000116.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000118.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000122.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000134.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000146.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big dog (INCORRECT)
#   Image: 000000000153.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000174.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000179.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000187.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000202.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big dog (INCORRECT)
#   Image: 000000000213.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000219.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000273.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000301.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000317.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000329.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000346.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000351.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000365.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000399.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000403.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000410.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000440.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000449.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000484.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big dog (INCORRECT)
#   Image: 000000000504.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000524.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000587.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000599.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000606.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000610.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000611.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000615.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000620.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000626.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000642.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000661.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000677.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000683.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000685.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000709.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000725.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000781.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000792.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000836.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big dog (INCORRECT)
#   Image: 000000000855.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000859.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000877.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000879.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000884.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000895.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000918.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000924.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000947.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000951.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000957.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000000982.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001000.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001028.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001034.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001040.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001052.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001090.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001100.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001116.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001131.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001147.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001172.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001200.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001210.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001217.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001243.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001298.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001307.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001360.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001373.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001375.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001438.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001455.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001491.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001495.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001502.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001505.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001520.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001526.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001531.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001540.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001549.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001563.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001568.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001580.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001588.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001595.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001608.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001617.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001619.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001652.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001689.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001692.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001717.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001762.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001822.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001826.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001873.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001881.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001886.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001909.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001929.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001949.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001977.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000001982.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002030.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002031.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002067.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002135.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002141.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002153.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002229.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002233.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002251.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002280.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002337.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002348.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002379.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002382.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002410.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002420.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002473.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002480.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002487.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002551.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002557.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002561.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002578.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002597.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002626.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002629.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002657.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002666.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002730.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002801.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002821.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002853.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002893.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002907.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002921.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002939.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002940.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002944.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000002959.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003005.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003008.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003026.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003074.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003080.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003101.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003111.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: bear (INCORRECT)
#   Image: 000000003130.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003145.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003181.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003194.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big dog (INCORRECT)
#   Image: 000000003222.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003224.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003245.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003250.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003254.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003279.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003317.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: bear (INCORRECT)
#   Image: 000000003339.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003346.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003358.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003385.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003409.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003420.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003434.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003464.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003471.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003482.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003487.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003507.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003508.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003542.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003545.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003560.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003572.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003575.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003576.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003584.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003593.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003636.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003652.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003686.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003719.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003728.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003752.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003790.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003811.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003818.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003892.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003920.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003944.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003960.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003979.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000003980.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000004014.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000004048.jpg
#     Ground Truth: big cat
#     Fusion Model Prediction: big cat (CORRECT)
#   Image: 000000004050.jpg
#     Ground Truth: big cat
# ...
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87927_IMG_0037.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87927_IMG_0056.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87928_IMG_0006.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87928_IMG_0012.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87928_IMG_0013.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87928_IMG_0029.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87933_IMG_0001.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87933_IMG_0004.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87934_IMG_0009.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87965_IMG_0003.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ87973_IMG_0002.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88053_IMG_0005.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88295_IMG_0004.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88295_IMG_0005.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88448_IMG_0002.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88458_IMG_0008.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88604_IMG_0004.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88604_IMG_0005.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88690_IMG_0013.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88703_IMG_0001.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ88703_IMG_0019.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ89252_IMG_0003.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90182_IMG_0001.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90182_IMG_0009.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90184_IMG_0004.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90184_IMG_0013.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90184_IMG_0016.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90184_IMG_0018.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90184_IMG_0023.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90256_IMG_0010.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90256_IMG_0023.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90256_IMG_0036.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90256_IMG_0049.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90317_IMG_0016.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90322_IMG_0021.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90322_IMG_0027.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90322_IMG_0030.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90379_IMG_0001.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: bear (INCORRECT)
#   Image: SEQ90379_IMG_0006.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90384_IMG_0001.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: big cat (INCORRECT)
#   Image: SEQ90384_IMG_0016.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90384_IMG_0017.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90384_IMG_0020.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90384_IMG_0021.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90384_IMG_0024.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90384_IMG_0027.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90384_IMG_0045.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90384_IMG_0047.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90384_IMG_0058.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90385_IMG_0001.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90389_IMG_0009.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90423_IMG_0002.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90448_IMG_0001.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90450_IMG_0021.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90450_IMG_0022.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90453_IMG_0004.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90453_IMG_0012.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90453_IMG_0025.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90453_IMG_0035.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90453_IMG_0039.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90453_IMG_0047.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90461_IMG_0002.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0004.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0024.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0031.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0046.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0051.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0056.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0064.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0066.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0078.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0081.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0083.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0087.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0088.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0091.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0094.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0100.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90482_IMG_0120.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90490_IMG_0004.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90498_IMG_0006.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90498_IMG_0012.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90498_IMG_0024.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90498_IMG_0029.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90507_IMG_0012.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90507_IMG_0017.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90507_IMG_0026.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90527_IMG_0009.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90550_IMG_0005.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90550_IMG_0007.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90550_IMG_0008.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90551_IMG_0001.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90551_IMG_0010.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90552_IMG_0036.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90552_IMG_0049.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90552_IMG_0072.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90552_IMG_0115.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90552_IMG_0125.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90552_IMG_0136.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90552_IMG_0138.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90554_IMG_0002.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90554_IMG_0009.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90555_IMG_0010.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90555_IMG_0018.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90555_IMG_0026.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0012.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0019.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0022.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0026.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: bear (INCORRECT)
#   Image: SEQ90556_IMG_0042.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0057.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0061.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0071.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0077.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0086.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0092.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0097.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0100.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0109.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0119.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90556_IMG_0120.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90557_IMG_0005.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90557_IMG_0016.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90558_IMG_0010.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90558_IMG_0019.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90558_IMG_0026.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90558_IMG_0029.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90558_IMG_0033.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90558_IMG_0038.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90558_IMG_0040.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90558_IMG_0044.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90559_IMG_0011.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90559_IMG_0013.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90559_IMG_0037.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90560_IMG_0002.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90560_IMG_0004.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90560_IMG_0014.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90560_IMG_0015.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90560_IMG_0017.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90561_IMG_0002.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90585_IMG_0006.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90585_IMG_0013.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90585_IMG_0017.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90585_IMG_0030.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90585_IMG_0035.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90586_IMG_0001.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90586_IMG_0002.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90586_IMG_0017.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: big dog (INCORRECT)
#   Image: SEQ90592_IMG_0004.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90592_IMG_0005.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90597_IMG_0007.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90597_IMG_0021.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90597_IMG_0049.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90606_IMG_0003.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90606_IMG_0014.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ90606_IMG_0035.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ91835_IMG_0008.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ91954_IMG_0005.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ91954_IMG_0006.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ91954_IMG_0011.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#   Image: SEQ92528_IMG_0006.JPG
#     Ground Truth: deer
#     Fusion Model Prediction: deer (CORRECT)
#
# --- Overall Results ---
# Total Images Evaluated: 1900
# Overall Correct Predictions: 1796
# Overall Incorrect Predictions: 104
# Overall Accuracy: 94.53%
