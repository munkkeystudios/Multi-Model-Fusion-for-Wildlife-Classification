# %% [markdown]
# # YOLO Image Classification Analysis

# %%
import os
import glob
import numpy as np
import torch
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from ultralytics import YOLO
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# %%
from ultralytics import YOLO

model = YOLO("yolo11x-cls.pt")   # or any other .pt file

# Short summary (layers + param counts)
model.info()

# Detailed, layer‑by‑layer summary
# model.info(detailed=False)
# Out:
# YOLO11x-cls summary: 176 layers, 29,637,064 parameters, 0 gradients, 112.0 GFLOPs
# (176, 29637064, 0, 112.0110592)

# %% [markdown]
# ## Load and Configure YOLO Classification Model

# %%
CLASS_DIRS = {
    "big cat":r"D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\test_dataset\big cat",
    "deer": r"D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\test_dataset\deer",
    "bear": r"D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\test_dataset\bear",
    "big dog": r"D:\SPRING 2025\Deep Learning\PROJECT\Datasets_MAIN\test_dataset\big dog"
}
model = YOLO("yolo11x-cls.pt")  #yolo classifier
conf_threshold = 0.25 

print(f"Class names: {model.names}")
# Out:
# Class names: {0: 'tench', 1: 'goldfish', 2: 'great_white_shark', 3: 'tiger_shark', 4: 'hammerhead', 5: 'electric_ray', 6: 'stingray', 7: 'cock', 8: 'hen', 9: 'ostrich', 10: 'brambling', 11: 'goldfinch', 12: 'house_finch', 13: 'junco', 14: 'indigo_bunting', 15: 'robin', 16: 'bulbul', 17: 'jay', 18: 'magpie', 19: 'chickadee', 20: 'water_ouzel', 21: 'kite', 22: 'bald_eagle', 23: 'vulture', 24: 'great_grey_owl', 25: 'European_fire_salamander', 26: 'common_newt', 27: 'eft', 28: 'spotted_salamander', 29: 'axolotl', 30: 'bullfrog', 31: 'tree_frog', 32: 'tailed_frog', 33: 'loggerhead', 34: 'leatherback_turtle', 35: 'mud_turtle', 36: 'terrapin', 37: 'box_turtle', 38: 'banded_gecko', 39: 'common_iguana', 40: 'American_chameleon', 41: 'whiptail', 42: 'agama', 43: 'frilled_lizard', 44: 'alligator_lizard', 45: 'Gila_monster', 46: 'green_lizard', 47: 'African_chameleon', 48: 'Komodo_dragon', 49: 'African_crocodile', 50: 'American_alligator', 51: 'triceratops', 52: 'thunder_snake', 53: 'ringneck_snake', 54: 'hognose_snake', 55: 'green_snake', 56: 'king_snake', 57: 'garter_snake', 58: 'water_snake', 59: 'vine_snake', 60: 'night_snake', 61: 'boa_constrictor', 62: 'rock_python', 63: 'Indian_cobra', 64: 'green_mamba', 65: 'sea_snake', 66: 'horned_viper', 67: 'diamondback', 68: 'sidewinder', 69: 'trilobite', 70: 'harvestman', 71: 'scorpion', 72: 'black_and_gold_garden_spider', 73: 'barn_spider', 74: 'garden_spider', 75: 'black_widow', 76: 'tarantula', 77: 'wolf_spider', 78: 'tick', 79: 'centipede', 80: 'black_grouse', 81: 'ptarmigan', 82: 'ruffed_grouse', 83: 'prairie_chicken', 84: 'peacock', 85: 'quail', 86: 'partridge', 87: 'African_grey', 88: 'macaw', 89: 'sulphur-crested_cockatoo', 90: 'lorikeet', 91: 'coucal', 92: 'bee_eater', 93: 'hornbill', 94: 'hummingbird', 95: 'jacamar', 96: 'toucan', 97: 'drake', 98: 'red-breasted_merganser', 99: 'goose', 100: 'black_swan', 101: 'tusker', 102: 'echidna', 103: 'platypus', 104: 'wallaby', 105: 'koala', 106: 'wombat', 107: 'jellyfish', 108: 'sea_anemone', 109: 'brain_coral', 110: 'flatworm', 111: 'nematode', 112: 'conch', 113: 'snail', 114: 'slug', 115: 'sea_slug', 116: 'chiton', 117: 'chambered_nautilus', 118: 'Dungeness_crab', 119: 'rock_crab', 120: 'fiddler_crab', 121: 'king_crab', 122: 'American_lobster', 123: 'spiny_lobster', 124: 'crayfish', 125: 'hermit_crab', 126: 'isopod', 127: 'white_stork', 128: 'black_stork', 129: 'spoonbill', 130: 'flamingo', 131: 'little_blue_heron', 132: 'American_egret', 133: 'bittern', 134: 'crane_(bird)', 135: 'limpkin', 136: 'European_gallinule', 137: 'American_coot', 138: 'bustard', 139: 'ruddy_turnstone', 140: 'red-backed_sandpiper', 141: 'redshank', 142: 'dowitcher', 143: 'oystercatcher', 144: 'pelican', 145: 'king_penguin', 146: 'albatross', 147: 'grey_whale', 148: 'killer_whale', 149: 'dugong', 150: 'sea_lion', 151: 'Chihuahua', 152: 'Japanese_spaniel', 153: 'Maltese_dog', 154: 'Pekinese', 155: 'Shih-Tzu', 156: 'Blenheim_spaniel', 157: 'papillon', 158: 'toy_terrier', 159: 'Rhodesian_ridgeback', 160: 'Afghan_hound', 161: 'basset', 162: 'beagle', 163: 'bloodhound', 164: 'bluetick', 165: 'black-and-tan_coonhound', 166: 'Walker_hound', 167: 'English_foxhound', 168: 'redbone', 169: 'borzoi', 170: 'Irish_wolfhound', 171: 'Italian_greyhound', 172: 'whippet', 173: 'Ibizan_hound', 174: 'Norwegian_elkhound', 175: 'otterhound', 176: 'Saluki', 177: 'Scottish_deerhound', 178: 'Weimaraner', 179: 'Staffordshire_bullterrier', 180: 'American_Staffordshire_terrier', 181: 'Bedlington_terrier', 182: 'Border_terrier', 183: 'Kerry_blue_terrier', 184: 'Irish_terrier', 185: 'Norfolk_terrier', 186: 'Norwich_terrier', 187: 'Yorkshire_terrier', 188: 'wire-haired_fox_terrier', 189: 'Lakeland_terrier', 190: 'Sealyham_terrier', 191: 'Airedale', 192: 'cairn', 193: 'Australian_terrier', 194: 'Dandie_Dinmont', 195: 'Boston_bull', 196: 'miniature_schnauzer', 197: 'giant_schnauzer', 198: 'standard_schnauzer', 199: 'Scotch_terrier', 200: 'Tibetan_terrier', 201: 'silky_terrier', 202: 'soft-coated_whea ...

# %% [markdown]
# ## Run Classification on Test Images

# %%
output_dir = "classification_results"
os.makedirs(output_dir, exist_ok=True)

test_images_by_class = {}
all_test_images = []

for class_name, class_dir in CLASS_DIRS.items():
    class_images = glob.glob(os.path.join(class_dir, "*.jpg")) + \
                   glob.glob(os.path.join(class_dir, "*.png"))
    test_images_by_class[class_name] = class_images
    all_test_images.extend(class_images)
    print(f"Found {len(class_images)} {class_name} images")

# Processed: SEQ77021_IMG_0015.JPG
# Processed: SEQ77022_IMG_0001.JPG
# Processed: SEQ77022_IMG_0004.JPG
# Processed: SEQ77022_IMG_0005.JPG
# Processed: SEQ77028_IMG_0013.JPG
# Processed: SEQ77046_IMG_0003.JPG
# Processed: SEQ77071_IMG_0002.JPG
# Processed: SEQ77071_IMG_0029.JPG
# Processed: SEQ77071_IMG_0046.JPG
# Processed: SEQ77071_IMG_0047.JPG
# Processed: SEQ77071_IMG_0048.JPG
# Processed: SEQ77071_IMG_0058.JPG
# Processed: SEQ77071_IMG_0063.JPG
# Processed: SEQ77071_IMG_0073.JPG
# Processed: SEQ77071_IMG_0075.JPG
# Processed: SEQ77075_IMG_0009.JPG
# Processed: SEQ77075_IMG_0021.JPG
# Processed: SEQ77075_IMG_0028.JPG
# Processed: SEQ77075_IMG_0035.JPG
# Processed: SEQ77075_IMG_0038.JPG
# Processed: SEQ77082_IMG_0005.JPG
# Processed: SEQ77082_IMG_0017.JPG
# Processed: SEQ77087_IMG_0003.JPG
# Processed: SEQ77089_IMG_0007.JPG
# Processed: SEQ77101_IMG_0004.JPG
# Processed: SEQ77101_IMG_0011.JPG
# Processed: SEQ77101_IMG_0012.JPG
# Processed: SEQ77101_IMG_0017.JPG
# Processed: SEQ77139_IMG_0005.JPG
# Processed: SEQ77139_IMG_0009.JPG
# Processed: SEQ77139_IMG_0010.JPG
# Processed: SEQ77139_IMG_0020.JPG
# Processed: SEQ77139_IMG_0023.JPG
# Processed: SEQ77147_IMG_0014.JPG
# Processed: SEQ77147_IMG_0015.JPG
# Processed: SEQ77147_IMG_0019.JPG
# Processed: SEQ77153_IMG_0011.JPG
# Processed: SEQ77231_IMG_0002.JPG
# Processed: SEQ77271_IMG_0011.JPG
# Processed: SEQ77350_IMG_0005.JPG
# Processed: SEQ77350_IMG_0010.JPG
# Processed: SEQ77381_IMG_0007.JPG
# Processed: SEQ77381_IMG_0008.JPG
# Processed: SEQ77381_IMG_0010.JPG
# Processed: SEQ77419_IMG_0004.JPG
# Processed: SEQ79460_IMG_0006.JPG
# Processed: SEQ79460_IMG_0016.JPG
# Processed: SEQ79460_IMG_0030.JPG
# Processed: SEQ79460_IMG_0031.JPG
# Processed: SEQ79460_IMG_0036.JPG
# Processed: SEQ79460_IMG_0038.JPG
# Processed: SEQ79460_IMG_0040.JPG
# Processed: SEQ79686_IMG_0001.JPG
# Processed: SEQ79686_IMG_0010.JPG
# Processed: SEQ79723_IMG_0001.JPG
# Processed: SEQ79723_IMG_0008.JPG
# Processed: SEQ79723_IMG_0014.JPG
# Processed: SEQ79723_IMG_0017.JPG
# Processed: SEQ79723_IMG_0027.JPG
# Processed: SEQ79732_IMG_0002.JPG
# Processed: SEQ79732_IMG_0003.JPG
# Processed: SEQ79761_IMG_0001.JPG
# Processed: SEQ79832_IMG_0003.JPG
# Processed: SEQ79876_IMG_0007.JPG
# Processed: SEQ79881_IMG_0009.JPG
# Processed: SEQ79881_IMG_0013.JPG
# Processed: SEQ87830_IMG_0012.JPG
# Processed: SEQ87830_IMG_0015.JPG
# Processed: SEQ87831_IMG_0005.JPG
# Processed: SEQ87865_IMG_0001.JPG
# Processed: SEQ87867_IMG_0001.JPG
# Processed: SEQ87867_IMG_0005.JPG
# Processed: SEQ87867_IMG_0007.JPG
# Processed: SEQ87867_IMG_0014.JPG
# Processed: SEQ87867_IMG_0015.JPG
# Processed: SEQ87868_IMG_0006.JPG
# Processed: SEQ87876_IMG_0014.JPG
# Processed: SEQ87876_IMG_0019.JPG
# Processed: SEQ87876_IMG_0022.JPG
# Processed: SEQ87876_IMG_0025.JPG
# Processed: SEQ87880_IMG_0001.JPG
# Processed: SEQ87892_IMG_0015.JPG
# Processed: SEQ87895_IMG_0001.JPG
# Processed: SEQ87895_IMG_0005.JPG
# Processed: SEQ87895_IMG_0015.JPG
# Processed: SEQ87895_IMG_0018.JPG
# Processed: SEQ87921_IMG_0004.JPG
# Processed: SEQ87924_IMG_0002.JPG
# Processed: SEQ87927_IMG_0009.JPG
# Processed: SEQ87927_IMG_0033.JPG
# Processed: SEQ87927_IMG_0035.JPG
# Processed: SEQ87927_IMG_0036.JPG
# Processed: SEQ87927_IMG_0037.JPG
# Processed: SEQ87927_IMG_0056.JPG
# Processed: SEQ87928_IMG_0006.JPG
# Processed: SEQ87928_IMG_0012.JPG
# Processed: SEQ87928_IMG_0013.JPG
# Processed: SEQ87928_IMG_0029.JPG
# Processed: SEQ87933_IMG_0001.JPG
# Processed: SEQ87933_IMG_0004.JPG
# Processed: SEQ87934_IMG_0009.JPG
# Processed: SEQ87965_IMG_0003.JPG
# Processed: SEQ87973_IMG_0002.JPG
# Processed: SEQ88053_IMG_0005.JPG
# Processed: SEQ88295_IMG_0004.JPG
# Processed: SEQ88295_IMG_0005.JPG
# Processed: SEQ88448_IMG_0002.JPG
# Processed: SEQ88458_IMG_0008.JPG
# Processed: SEQ88604_IMG_0004.JPG
# Processed: SEQ88604_IMG_0005.JPG
# Processed: SEQ88690_IMG_0013.JPG
# Processed: SEQ88703_IMG_0001.JPG
# Processed: SEQ88703_IMG_0019.JPG
# Processed: SEQ89252_IMG_0003.JPG
# Processed: SEQ90182_IMG_0001.JPG
# Processed: SEQ90182_IMG_0009.JPG
# Processed: SEQ90184_IMG_0004.JPG
# Processed: SEQ90184_IMG_0013.JPG
# Processed: SEQ90184_IMG_0016.JPG
# Processed: SEQ90184_IMG_0018.JPG
# Processed: SEQ90184_IMG_0023.JPG
# Processed: SEQ90256_IMG_0010.JPG
# Processed: SEQ90256_IMG_0023.JPG
# Processed: SEQ90256_IMG_0036.JPG
# Processed: SEQ90256_IMG_0049.JPG
# Processed: SEQ90317_IMG_0016.JPG
# Processed: SEQ90322_IMG_0021.JPG
# Processed: SEQ90322_IMG_0027.JPG
# Processed: SEQ90322_IMG_0030.JPG
# Processed: SEQ90379_IMG_0001.JPG
# Processed: SEQ90379_IMG_0006.JPG
# Processed: SEQ90384_IMG_0001.JPG
# Processed: SEQ90384_IMG_0016.JPG
# Processed: SEQ90384_IMG_0017.JPG
# Processed: SEQ90384_IMG_0020.JPG
# Processed: SEQ90384_IMG_0021.JPG
# Processed: SEQ90384_IMG_0024.JPG
# Processed: SEQ90384_IMG_0027.JPG
# Processed: SEQ90384_IMG_0045.JPG
# Processed: SEQ90384_IMG_0047.JPG
# Processed: SEQ90384_IMG_0058.JPG
# Processed: SEQ90385_IMG_0001.JPG
# Processed: SEQ90389_IMG_0009.JPG
# Processed: SEQ90423_IMG_0002.JPG
# Processed: SEQ90448_IMG_0001.JPG
# Processed: SEQ90450_IMG_0021.JPG
# Processed: SEQ90450_IMG_0022.JPG
# Processed: SEQ90453_IMG_0004.JPG
# Processed: SEQ90453_IMG_0012.JPG
# Processed: SEQ90453_IMG_0025.JPG
# Processed: SEQ90453_IMG_0035.JPG
# Processed: SEQ90453_IMG_0039.JPG
# Processed: SEQ90453_IMG_0047.JPG
# Processed: SEQ90461_IMG_0002.JPG
# Processed: SEQ90482_IMG_0004.JPG
# Processed: SEQ90482_IMG_0024.JPG
# Processed: SEQ90482_IMG_0031.JPG
# Processed: SEQ90482_IMG_0046.JPG
# Processed: SEQ90482_IMG_0051.JPG
# Processed: SEQ90482_IMG_0056.JPG
# Processed: SEQ90482_IMG_0064.JPG
# Processed: SEQ90482_IMG_0066.JPG
# Processed: SEQ90482_IMG_0078.JPG
# Processed: SEQ90482_IMG_0081.JPG
# Processed: SEQ90482_IMG_0083.JPG
# Processed: SEQ90482_IMG_0087.JPG
# Processed: SEQ90482_IMG_0088.JPG
# Processed: SEQ90482_IMG_0091.JPG
# Processed: SEQ90482_IMG_0094.JPG
# Processed: SEQ90482_IMG_0100.JPG
# Processed: SEQ90482_IMG_0120.JPG
# Processed: SEQ90490_IMG_0004.JPG
# Processed: SEQ90498_IMG_0006.JPG
# Processed: SEQ90498_IMG_0012.JPG
# Processed: SEQ90498_IMG_0024.JPG
# Processed: SEQ90498_IMG_0029.JPG
# Processed: SEQ90507_IMG_0012.JPG
# Processed: SEQ90507_IMG_0017.JPG
# Processed: SEQ90507_IMG_0026.JPG
# Processed: SEQ90527_IMG_0009.JPG
# Processed: SEQ90550_IMG_0005.JPG
# Processed: SEQ90550_IMG_0007.JPG
# Processed: SEQ90550_IMG_0008.JPG
# Processed: SEQ90551_IMG_0001.JPG
# Processed: SEQ90551_IMG_0010.JPG
# Processed: SEQ90552_IMG_0036.JPG
# Processed: SEQ90552_IMG_0049.JPG
# Processed: SEQ90552_IMG_0072.JPG
# Processed: SEQ90552_IMG_0115.JPG
# Processed: SEQ90552_IMG_0125.JPG
# Processed: SEQ90552_IMG_0136.JPG
# Processed: SEQ90552_IMG_0138.JPG
# Processed: SEQ90554_IMG_0002.JPG
# Processed: SEQ90554_IMG_0009.JPG
# Processed: SEQ90555_IMG_0010.JPG
# Processed: SEQ90555_IMG_0018.JPG
# Processed: SEQ90555_IMG_0026.JPG
# Processed: SEQ90556_IMG_0012.JPG
# Processed: SEQ90556_IMG_0019.JPG
# Processed: SEQ90556_IMG_0022.JPG
# Processed: SEQ90556_IMG_0026.JPG
# Processed: SEQ90556_IMG_0042.JPG
# Processed: SEQ90556_IMG_0057.JPG
# Processed: SEQ90556_IMG_0061.JPG
# Processed: SEQ90556_IMG_0071.JPG
# Processed: SEQ90556_IMG_0077.JPG
# Processed: SEQ90556_IMG_0086.JPG
# Processed: SEQ90556_IMG_0092.JPG
# Processed: SEQ90556_IMG_0097.JPG
# Processed: SEQ90556_IMG_0100.JPG
# Processed: SEQ90556_IMG_0109.JPG
# Processed: SEQ90556_IMG_0119.JPG
# Processed: SEQ90556_IMG_0120.JPG
# Processed: SEQ90557_IMG_0005.JPG
# Processed: SEQ90557_IMG_0016.JPG
# Processed: SEQ90558_IMG_0010.JPG
# Processed: SEQ90558_IMG_0019.JPG
# Processed: SEQ90558_IMG_0026.JPG
# Processed: SEQ90558_IMG_0029.JPG
# Processed: SEQ90558_IMG_0033.JPG
# Processed: SEQ90558_IMG_0038.JPG
# Processed: SEQ90558_IMG_0040.JPG
# Processed: SEQ90558_IMG_0044.JPG
# Processed: SEQ90559_IMG_0011.JPG
# Processed: SEQ90559_IMG_0013.JPG
# Processed: SEQ90559_IMG_0037.JPG
# Processed: SEQ90560_IMG_0002.JPG
# Processed: SEQ90560_IMG_0004.JPG
# Processed: SEQ90560_IMG_0014.JPG
# Processed: SEQ90560_IMG_0015.JPG
# Processed: SEQ90560_IMG_0017.JPG
# Processed: SEQ90561_IMG_0002.JPG
# Processed: SEQ90585_IMG_0006.JPG
# Processed: SEQ90585_IMG_0013.JPG
# Processed: SEQ90585_IMG_0017.JPG
# Processed: SEQ90585_IMG_0030.JPG
# Processed: SEQ90585_IMG_0035.JPG
# Processed: SEQ90586_IMG_0001.JPG
# Processed: SEQ90586_IMG_0002.JPG
# Processed: SEQ90586_IMG_0017.JPG
# Processed: SEQ90592_IMG_0004.JPG
# Processed: SEQ90592_IMG_0005.JPG
# Processed: SEQ90597_IMG_0007.JPG
# Processed: SEQ90597_IMG_0021.JPG
# Processed: SEQ90597_IMG_0049.JPG
# Processed: SEQ90606_IMG_0003.JPG
# Processed: SEQ90606_IMG_0014.JPG
# Processed: SEQ90606_IMG_0035.JPG
# Processed: SEQ91835_IMG_0008.JPG
# Processed: SEQ91954_IMG_0005.JPG
# Processed: SEQ91954_IMG_0006.JPG
# Processed: SEQ91954_IMG_0011.JPG
# Processed: SEQ92528_IMG_0006.JPG
# Processed: 8784.jpg
# Processed: 8789.jpg
# Processed: 8794.jpg
# Processed: 8795.jpg
# Processed: 8796.jpg
# Processed: 8797.jpg
# Processed: 8798.jpg
# Processed: 8799.jpg
# Processed: 8801.jpg
# Processed: 8803.jpg
# Processed: 8804.jpg
# Processed: 8821.jpg
# Processed: 8823.jpg
# Processed: 8824.jpg
# Processed: 8825.jpg
# Processed: 8826.jpg
# Processed: 8828.jpg
# Processed: 8836.jpg
# Processed: 8837.jpg
# Processed: 8838.jpg
# Processed: 8839.jpg
# Processed: 8840.jpg
# Processed: 8843.jpg
# Processed: 000000002965.jpg
# Processed: 000000002966.jpg
# Processed: 000000002978.jpg
# Processed: 000000002981.jpg
# Processed: 000000002988.jpg
# Processed: 000000002989.jpg
# Processed: 000000002998.jpg
# Processed: 000000003009.jpg
# Processed: 000000003012.jpg
# Processed: 000000003018.jpg
# Processed: 000000003022.jpg
# Processed: 000000003023.jpg
# Processed: 000000003024.jpg
# Processed: 000000003029.jpg
# Processed: 000000003046.jpg
# Processed: 000000003053.jpg
# Processed: 000000003055.jpg
# Processed: 000000003065.jpg
# Processed: 000000003067.jpg
# Processed: 000000003089.jpg
# Processed: 000000003090.jpg
# Processed: 000000003098.jpg
# Processed: 000000003100.jpg
# Classification completed on all test images

# %% [markdown]
# ## Extract Results from Classification Output

# %%
def extract_classifications(results):
    all_predictions = []
    
    for i, result in enumerate(results):
        img_name = os.path.basename(result.path)
        probs = result.probs 
        
        top_class_id = int(probs.top1)
        top_class_name = result.names[top_class_id]
        top_confidence = float(probs.top1conf)
        
        prediction = {
            'image': img_name,
            'class_id': top_class_id,
            'class_name': top_class_name,
            'confidence': top_confidence
        }
        all_predictions.append(prediction)
    
    return all_predictions

predictions = extract_classifications(results_list)

prediction_df = pd.DataFrame(predictions)

print(f"Total classifications: {len(prediction_df)}")
display(prediction_df.head())

class_counts = prediction_df['class_name'].value_counts()
print("\nPredictions by class:")
print(class_counts)
# Out:
# Total classifications: 1900
#               image  class_id class_name  confidence
# 0  000000000033.jpg       293    cheetah    0.767675
# 1  000000000070.jpg       293    cheetah    0.534940
# 2  000000000094.jpg       288    leopard    0.762987
# 3  000000000095.jpg       288    leopard    0.763210
# 4  000000000105.jpg       288    leopard    0.747836
# Predictions by class:
# class_name
# hyena                  461
# leopard                205
# American_black_bear    132
# cheetah                103
# tiger                   98
#                       ...
# volcano                  1
# Angora                   1
# car_mirror               1
# Indian_elephant          1
# hen-of-the-woods         1
# Name: count, Length: 153, dtype: int64

# %%
prediction_df.to_csv(os.path.join(output_dir, "classification_results.csv"), index=False)
print(f"Classification results saved to {os.path.join(output_dir, 'classification_results.csv')}")
# Out:
# Classification results saved to classification_results\classification_results.csv

# %% [markdown]
# ## Calculate and Display Metrics

# %%
def load_ground_truth(test_images_by_class):
    ground_truth = []
    
    for class_name, image_list in test_images_by_class.items():
        for img_path in image_list:
            img_name = os.path.basename(img_path)
            ground_truth.append({
                'image': img_name,
                'class': class_name
            })
    
    return ground_truth

ground_truth = load_ground_truth(test_images_by_class)
have_ground_truth = True

# %%
if have_ground_truth:
    gt_dict = {item['image']: item['class'] for item in ground_truth}
    
    y_true = []
    y_pred = []
    y_pred_original = [] 
    class_names = list(CLASS_DIRS.keys())
    
    big_cats = ['tiger', 'lion', 'leopard', 'cheetah', 'jaguar', 'puma', 'lynx', 'cougar', 'panther', 'snow leopard']
    bears = ['bear', 'brown bear', 'polar bear', 'grizzly', 'black bear', 'panda', 'American_black_bear']
    deers = ['deer', 'elk', 'moose', 'reindeer', 'antelope', 'gazelle', 'impala']
    big_dogs = ['wolf', 'coyote', 'fox', 'hyena', 'jackal', 'dingo', 'wild dog']
    
    def standardized_class(pred_class):
        pred_lower = pred_class.lower()
        
        for animal in big_cats:
            if animal.lower() in pred_lower:
                return "big cat"
        
        for animal in bears:
            if animal.lower() in pred_lower:
                return "bear"
        
        for animal in deers:
            if animal.lower() in pred_lower:
                return "deer"
        
        for animal in big_dogs:
            if animal.lower() in pred_lower:
                return "big dog"
        
        return pred_class
    
    def is_correct_prediction(true_class, pred_class):
        if true_class == pred_class:
            return True
        
        standardized = standardized_class(pred_class)
        return standardized == true_class
    
    for img_path in all_test_images:
        img_name = os.path.basename(img_path)
        true_class = gt_dict.get(img_name, None)
        
        if true_class:
            y_true.append(true_class)
            
            pred_row = prediction_df[prediction_df['image'] == img_name]
            if not pred_row.empty:
                pred_class = pred_row.iloc[0]['class_name']
                y_pred_original.append(pred_class)  
                
                standardized_pred = standardized_class(pred_class)
                y_pred.append(standardized_pred)
            else:
                y_pred.append(None)
                y_pred_original.append(None)
    
    print("\nmetrics by Class:")
    for target_class in class_names:
        correct_preds = 0
        incorrect_preds = 0
        
        for i, true_class in enumerate(y_true):
            if true_class == target_class:
                if is_correct_prediction(true_class, y_pred_original[i]):
                    correct_preds += 1
                else:
                    incorrect_preds += 1
                    
        total = correct_preds + incorrect_preds
        accuracy = correct_preds / total if total > 0 else 0
        
        binary_true = [1 if c == target_class else 0 for c in y_true]
        binary_pred = [1 if is_correct_prediction(target_class, p) else 0 for p in y_pred_original]
        
        precision = precision_score(binary_true, binary_pred, zero_division=0)
        recall = recall_score(binary_true, binary_pred, zero_division=0)
        f1 = f1_score(binary_true, binary_pred, zero_division=0)
        
        print(f"\n{target_class.capitalize()} Metrics:")
        print(f"Total samples: {total}")
        print(f"Correct predictions: {correct_preds} ({correct_preds/total*100:.2f}%)")
        print(f"Incorrect predictions: {incorrect_preds} ({incorrect_preds/total*100:.2f}%)")
        print(f"Accuracy: {accuracy:.3f}")
        print(f"Precision: {precision:.3f}")
        print(f"Recall: {recall:.3f}")
        print(f"F1 Score: {f1:.3f}")
    
    total_correct = sum(1 for i, true_class in enumerate(y_true) 
                      if is_correct_prediction(true_class, y_pred_original[i]))
    total_samples = len(y_true)
    overall_accuracy = total_correct / total_samples if total_samples > 0 else 0
    
    standardized_y_pred = []
    for i, true_val in enumerate(y_true):
        orig_pred = y_pred_original[i]
        if is_correct_prediction(true_val, orig_pred):
            standardized_y_pred.append(true_val)
        else:
            standardized_y_pred.append(orig_pred)
    
    macro_precision = precision_score(y_true, standardized_y_pred, average='macro', zero_division=0)
    macro_recall = recall_score(y_true, standardized_y_pred, average='macro', zero_division=0)
    macro_f1 = f1_score(y_true, standardized_y_pred, average='macro', zero_division=0)
    
    weighted_precision = precision_score(y_true, standardized_y_pred, average='weighted', zero_division=0)
    weighted_recall = recall_score(y_true, standardized_y_pred, average='weighted', zero_division=0)
    weighted_f1 = f1_score(y_true, standardized_y_pred, average='weighted', zero_division=0)
    
    print("\n== Overall Metrics ==")
    print(f"Total samples: {total_samples}")
    print(f"Correct predictions: {total_correct} ({total_correct/total_samples*100:.2f}%)")
    print(f"Overall accuracy: {overall_accuracy:.3f}")
    print("\nMacro Average (treat all classes equally):")
    print(f"Precision: {macro_precision:.3f}")
    print(f"Recall: {macro_recall:.3f}")
    print(f"F1 Score: {macro_f1:.3f}")
    print("\nWeighted Average (weighted by class support):")
    print(f"Precision: {weighted_precision:.3f}")
    print(f"Recall: {weighted_recall:.3f}")
    print(f"F1 Score: {weighted_f1:.3f}")
    
    # Continue with confusion matrix
    cm = confusion_matrix(y_true, standardized_y_pred, labels=class_names)
    
    plt.figure(figsize=(10, 8))
    ax = sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)
    
    plt.ylim(len(class_names), 0)    
    plt.xlabel('Pred')
    plt.ylabel('Actual')
    plt.title('Multi class Confusion Matrix')
    
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    
    plt.tight_layout()
    plt.show()
# Out:
# metrics by Class:
#
# Big cat Metrics:
# Total samples: 477
# Correct predictions: 391 (81.97%)
# Incorrect predictions: 86 (18.03%)
# Accuracy: 0.820
# Precision: 0.869
# Recall: 0.820
# F1 Score: 0.844
#
# Deer Metrics:
# Total samples: 600
# Correct predictions: 95 (15.83%)
# Incorrect predictions: 505 (84.17%)
# Accuracy: 0.158
# Precision: 0.979
# Recall: 0.158
# F1 Score: 0.273
#
# Bear Metrics:
# Total samples: 300
# Correct predictions: 128 (42.67%)
# Incorrect predictions: 172 (57.33%)
# Accuracy: 0.427
# Precision: 0.921
# Recall: 0.427
# F1 Score: 0.583
#
# Big dog Metrics:
# Total samples: 523
# Correct predictions: 448 (85.66%)
# Incorrect predictions: 75 (14.34%)
# Accuracy: 0.857
# Precision: 0.794
# Recall: 0.857
# F1 Score: 0.824
#
# ==== Overall Metrics ====
# Total samples: 1900
# Correct predictions: 1062 (55.89%)
# Overall accuracy: 0.559
#
# Macro Average (treat all classes equally):
# Precision: 0.027
# Recall: 0.015
# F1 Score: 0.018
#
# Weighted Average (weighted by class support):
# Precision: 1.000
# Recall: 0.559
# F1 Score: 0.661

# %% [markdown]
# ## Visualizing Results

# %%
def plot_classification_examples(results_list, test_images_by_class, num_per_class=2):
    for class_name in CLASS_DIRS.keys():
        class_paths = test_images_by_class[class_name]
        if not class_paths:
            continue
            
        samples = class_paths[:num_per_class]
        fig, axs = plt.subplots(1, len(samples), figsize=(15, 5))
        if len(samples) == 1:
            axs = [axs]  
            
        fig.suptitle(f"{class_name.capitalize()} Examples", fontsize=16)
        
        for i, img_path in enumerate(samples):
            img_name = os.path.basename(img_path)
            pred_row = prediction_df[prediction_df['image'] == img_name]
            pred_class = pred_row.iloc[0]['class_name'] if not pred_row.empty else 'Unknown'
            confidence = pred_row.iloc[0]['confidence'] if not pred_row.empty else 0
            
            img = Image.open(img_path)
            axs[i].imshow(img)
            
            color = 'green' if pred_class == class_name else 'red'
            title = f"True: {class_name}\nPred: {pred_class} ({confidence:.2f})"
            axs[i].set_title(title, color=color)
            axs[i].axis('off')
            
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()
        
plot_classification_examples(results_list, test_images_by_class)
